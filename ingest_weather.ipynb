# %%
import os
import requests
from datetime import datetime

# %%
# 1. SETUP & CONFIGURATION
# Set your API key in your terminal/environment variables before running
# Example: export OPENWEATHER_API_KEY='your_key_here'
API_KEY = os.getenv("OPENWEATHER_API_KEY")

# Step 1: The 30 largest cities in the EU by population
CITIES = [
    "Berlin", "Madrid", "Rome", "Paris", "Vienna", 
    "Warsaw", "Hamburg", "Barcelona", "Bucharest", "Budapest",
    "Munich", "Prague", "Milan", "Sofia", "Cologne", 
    "Stockholm", "Amsterdam", "Naples", "Marseille", "Turin",
    "Valencia", "Kraków", "Zagreb", "Frankfurt", "Zaragoza", 
    "Seville", "Helsinki", "Rotterdam", "Wrocław", "Copenhagen"
]

def fetch_weather_data():
    all_city_data = []
    
    # Step 2: The API Request Logic
    for city in CITIES:
        try:
            print(f"Fetching data for {city}...")
            
            # --- PART A: GET WEATHER & COORDINATES ---
            # You need the coordinates (lat/lon) to get air pollution data
            # Hint: Use the 'units=metric' parameter for Celsius
            weather_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}"
            
            # TODO: Use requests.get() to call weather_url
            # TODO: Extract lat and lon from the response JSON
            
            # --- PART B: GET AIR POLLUTION ---
            # The pollution API uses coordinates instead of city names
            # pollution_url = f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={API_KEY}"
            
            # TODO: Use requests.get() to call pollution_url
            
            # --- PART C: COMBINE & FORMAT ---
            # Create a dictionary containing exactly what you want in BigQuery
            city_record = {
                "city": city,
                "timestamp": datetime.datetime.utcnow().isoformat(),
                "temperature": None, # TODO: Get from weather response
                "humidity": None,    # TODO: Get from weather response
                "aqi": None          # TODO: Get from pollution response (Air Quality Index)
            }
            
            all_city_data.append(city_record)
            
        except Exception as e:
            print(f"Error fetching data for {city}: {e}")
            
    return all_city_data

if __name__ == "__main__":
    data = fetch_weather_data()
    print(f"Successfully collected data for {len(data)} cities.")
# Out:
# /var/folders/dg/0cb4kz39071fd_r66gfxjbj80000gn/T/ipykernel_8268/1889658027.py:50: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "ingested_at": datetime.utcnow().isoformat()
# Successfully fetched Berlin: Temp 10.15°C, AQI 1
# Successfully fetched Madrid: Temp 10.6°C, AQI 1
# Successfully fetched Rome: Temp 11.6°C, AQI 1
# Successfully fetched Paris: Temp 14.83°C, AQI 2
# Successfully fetched Vienna: Temp 4.68°C, AQI 2
# Successfully fetched Warsaw: Temp 3.19°C, AQI 3
# Successfully fetched Hamburg: Temp 9.87°C, AQI 1
# Successfully fetched Barcelona: Temp 16.09°C, AQI 2
# Successfully fetched Bucharest: Temp 6.05°C, AQI 2
# Successfully fetched Budapest: Temp 4.69°C, AQI 2
# Successfully fetched Munich: Temp 10.26°C, AQI 1
# Successfully fetched Prague: Temp 2.68°C, AQI 2
# Successfully fetched Milan: Temp 10.4°C, AQI 1
# ...
